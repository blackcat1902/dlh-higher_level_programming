# %%
#!/usr/bin/python3
for i in range(97, 123):
    if i != 101 and i != 113:
        print("{}".format(chr(i)), end="")
# Out:
# a
# b
# c
# d
# f
# g
# h
# i
# j
# k
# l
# m
# n
# o
# p
# r
# s
# t
# u
# v
# w
# x
# y
# z
